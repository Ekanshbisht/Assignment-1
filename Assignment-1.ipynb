# %% [raw]
# Q1. Create one variable containing following type of data:
# (i) string
# (ii) list
# (iii) float
# (iv) tuple
#
# Ans:
# (i) string
# my_string = "Hello, world!"
#
# (ii) list
# my_list = [1, 2, 3, 4, 5]
#
# (iii) float
# my_float = 3.14
#
# (iv) tuple
# my_tuple = (1, "apple", True)
#
#
# Q2. Given are some following variables containing data:
# (i) var1 = ‘ ‘
# (ii) var2 = ‘[ DS , ML , Python]’
# (iii) var3 = [ ‘DS’ , ’ML’ , ‘Python’ ]
# (iv) var4 = 1.
#
# Ans:
#
# (i) var1 = ' ' (a string variable containing a single space)
# This variable var1 is a string that contains a single space character.
#
# (ii) var2 = '[DS, ML, Python]' (a string variable containing a list-like representation as a string)
# This variable var2 is a string that represents a list. However, it is stored as a string, including the square brackets and commas.
#
# (iii) var3 = ['DS', 'ML', 'Python'] (a list variable containing strings)
# This variable var3 is a list that contains three string elements: 'DS', 'ML', and 'Python'.
#
# (iv) var4 = 1 (an integer variable)
# This variable var4 is an integer and its value is 1.
#
#
# Q3. Explain the use of the following operators using an example:
# (i) /
# (ii) %
# (iii) //
# (iv) **
#
# Ans:
#
# (i) / (Division Operator):
# The division operator is used to divide one number by another. It performs floating-point division, which means it returns a floating-point result.
#
# Example:
# x = 10 / 3
# print(x)
#
# output:
# 3.3333333333333335
#
# In this example, the division operator / divides 10 by 3, resulting in a floating-point value of approximately 3.3333333333333335.
#
#
# (ii) % (Modulus Operator):
# The modulus operator is used to find the remainder when one number is divided by another.
#
# Example:
# x = 10 % 3
# print(x)
#
# ouput:
# 1
#
# In this example, the modulus operator % calculates the remainder when 10 is divided by 3, which is 1.
#
# (iii) // (Floor Division Operator):
# The floor division operator performs division between two numbers and returns the quotient rounded down to the nearest whole number.
#
# Example:
#
# x = 10 // 3
# print(x)
#
# Output:
#
# 3
#
# In this example, the floor division operator // divides 10 by 3, resulting in a quotient of 3 (rounding down).
#
#
# (iv) ** (Exponentiation Operator):
# The exponentiation operator raises a number to a power.
#
# Example:
#
# x = 2 ** 3
# print(x)
#
# Output:
#
# 8
#
# In this example, the exponentiation operator ** raises 2 to the power of 3, resulting in 8.
#
#
#
# Q4. Create a list of length 10 of your choice containing multiple types of data. Using for loop print the
# element and its data type.
#
# Ans:
#  Here's an example of creating a list of length 10 with different types of data and printing each element along with its data type using a for loop:
#
#  my_list = [1, 'apple', 3.14, True, [1, 2, 3], 'banana', 5, False, (1, 2, 3), 'orange']
#
# for item in my_list:
#     print(item, type(item))
#
# Output:
#
# 1 <class 'int'>
# apple <class 'str'>
# 3.14 <class 'float'>
# True <class 'bool'>
# [1, 2, 3] <class 'list'>
# banana <class 'str'>
# 5 <class 'int'>
# False <class 'bool'>
# (1, 2, 3) <class 'tuple'>
# orange <class 'str'>
#
# In this example, the my_list variable is a list of length 10 that contains elements of different types, such as integers, strings, floats, booleans, lists, and tuples. The for loop iterates over each item in the list, and for each item, it prints the item itself along with its corresponding data type using the type() function.
#
# Q5. Using a while loop, verify if the number A is purely divisible by number B and if so then how many
# times it can be divisible.
#
# Ans:
# Here's an example of using a while loop to verify if number A is divisible by number B and, if so, counting how many times it can be divided:
#
# A = 120
# B = 6
# count = 0
#
# while A % B == 0:
#     A = A / B
#     count += 1
#
# print("Number A can be divided by number B", count, "times.")
#
# output:
#
# Number A can be divided by number B 2 times.
#
# In this example, we have number A as 120 and number B as 6. The while loop checks if A is divisible by B by checking if the remainder of A divided by B is 0. If it is, it means A is divisible by B, and the loop continues. Inside the loop, A is divided by B, and the count variable keeps track of how many times A has been divided by B.
#
# Once the condition A % B != 0 is met, the loop stops, and we print the number of times A was divisible by B using the count variable. In this case, 120 can be divided by 6 two times evenly.
#
# Q6. Create a list containing 25 int type data. Using for loop and if-else condition print if the element is
# divisible by 3 or not.
#
# Ans:
# Here's an example of creating a list containing 25 integers and using a for loop with an if-else condition to check if each element is divisible by 3 or not:
#
# my_list = [12, 5, 9, 18, 27, 6, 14, 21, 30, 8, 16, 33, 11, 22, 3, 25, 36, 7, 15, 24, 10, 19, 28, 17, 31]
#
# for element in my_list:
#     if element % 3 == 0:
#         print(element, "is divisible by 3")
#     else:
#         print(element, "is not divisible by 3")
#
# Output:
#
# 12 is divisible by 3
# 5 is not divisible by 3
# 9 is divisible by 3
# 18 is divisible by 3
# 27 is divisible by 3
# 6 is divisible by 3
# 14 is not divisible by 3
# 21 is divisible by 3
# 30 is divisible by 3
# 8 is not divisible by 3
# 16 is not divisible by 3
# 33 is divisible by 3
# 11 is not divisible by 3
# 22 is not divisible by 3
# 3 is divisible by 3
# 25 is not divisible by 3
# 36 is divisible by 3
# 7 is not divisible by 3
# 15 is divisible by 3
# 24 is divisible by 3
# 10 is not divisible by 3
# 19 is not divisible by 3
# 28 is not divisible by 3
# 17 is not divisible by 3
# 31 is not divisible by 3
#
# In this example, we have a list my_list containing 25 integer elements. The for loop iterates over each element in the list. Inside the loop, we use an if-else condition to check if the element is divisible by 3. If the remainder of the division operation element % 3 is 0, then it is divisible by 3, and we print that the element is divisible by 3. Otherwise, we print that the element is not divisible by 3.
#
# Q7. What do you understand about mutable and immutable data types? Give examples for both showing
# this property.
#
# Ans:
# In programming, mutable and immutable are terms used to describe whether an object's value can be changed after it is created. Here's an explanation of mutable and immutable data types:
#
# Mutable Data Types:
# Mutable data types are those that can be modified or changed after they are created. This means you can update, add, or remove elements of a mutable object without creating a new object.
# Examples of mutable data types in Python include:
#
# Lists: Lists can be modified by adding or removing elements.
#
# my_list = [1, 2, 3]
# my_list.append(4)  # Add an element
# my_list.remove(2)  # Remove an element
# print(my_list)  # Output: [1, 3, 4]
#
# Dictionaries: Dictionaries can have key-value pairs added, removed, or modified.
# python
# my_dict = {'name': 'John', 'age': 25}
# my_dict['age'] = 26  # Modify a value
# my_dict['city'] = 'New York'  # Add a new key-value pair
# del my_dict['name']  # Remove a key-value pair
# print(my_dict)  # Output: {'age': 26, 'city': 'New York'}
#
# Immutable Data Types:
# Immutable data types, on the other hand, cannot be changed after they are created. If you need to modify an immutable object, you have to create a new object.
# Examples of immutable data types in Python include:
#
# Strings: Strings cannot be modified in-place; you need to create a new string.
#
# my_string = "Hello"
# new_string = my_string + " World"  # Concatenate strings
# print(my_string)  # Output: "Hello"
# print(new_string)  # Output: "Hello World"
#
# Tuples: Tuples are similar to lists, but they are immutable.
#
# my_tuple = (1, 2, 3)
# # Trying to modify a tuple will result in an error
# # my_tuple[0] = 4  # Raises an error
#
# Immutable objects ensure data integrity and are useful in situations where you want to guarantee that an object's value remains unchanged.
#
# By understanding the concept of mutable and immutable data types, you can make informed decisions on which type to use based on your program's requirements.
